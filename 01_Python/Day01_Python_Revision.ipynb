# %% [markdown]
# # Project Atlas - Day 1
#
# ## Python Revision
#
# Topics:
# - Functions
# - *args
# - **kwargs
# - Lambda Functions
# - List Comprehensions

# %%
def square(n):
    return n * n

print("If this doesn't say 25, Python is broken:")
print(square(5))
# Out:
# If this doesn't say 25, Python is broken:
# 25
